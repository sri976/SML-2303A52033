# %% [markdown]
# <a href="https://colab.research.google.com/github/sri976/SML-2303A52033/blob/main/SML_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv('/content/drive/MyDrive/archive.zip',usecols=(['UserID','Age']))
data.head()
#print(data)
data.shape
#data.info()
data.describe()
data.skew()
data.kurt()
# Out:
# UserID   -1.20000
# Age      -1.13587
# dtype: float64

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
plt.plot(data, color='r')
plt.show()

# %%
x=data.drop('Age',axis=1)
y=data.Age
from sklearn import linear_model
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (800, 1)
# (200, 1)
# (800,)
# (200,)

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(x_train,y_train)
reg.intercept_
reg.coef_
# Out:
# array([0.00058374])

# %%
y_pred=reg.predict(x_test)
y_pred
# Out:
# array([39.47424003, 39.3960187 , 39.06853984, 39.21739386, 39.28685908,
#        39.46139772, 38.91034595, 39.02942917, 39.07320977, 39.30670628,
#        39.18412061, 39.22031257, 39.3522381 , 39.0340991 , 39.2319874 ,
#        38.92669071, 39.42345454, 38.99673966, 38.90275731, 38.93953301,
#        38.91268092, 39.17536449, 39.07554473, 39.07612847, 39.41002849,
#        39.35457307, 38.92085329, 38.95471029, 39.33822831, 38.89516868,
#        39.37500401, 39.30904125, 39.25300208, 39.35574055, 39.13275138,
#        39.32421852, 39.45322534, 39.10823425, 39.43045943, 39.05044386,
#        39.02884543, 39.47599125, 39.26526065, 39.30203635, 39.041104  ,
#        39.35165436, 39.37266905, 38.97689246, 39.07904718, 39.23724107,
#        39.0878033 , 39.06678861, 39.04752515, 39.14676117, 39.39776992,
#        39.23432236, 39.05336256, 39.05219508, 39.47073758, 39.0807984 ,
#        39.22673373, 39.26993058, 38.9774762 , 39.01250067, 39.13567009,
# ...

# %%
y_test
# Out:
# 993    24
# 859    27
# 298    31
# 553    44
# 672    58
#        ..
# 679    49
# 722    35
# 215    59
# 653    24
# 150    39
# Name: Age, Length: 200, dtype: int64

# %%
from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,y_pred))
# Out:
# Mean Absolute Error: 10.86287734689207
# Mean Squared Error: 152.53933764657438
